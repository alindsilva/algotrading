# %% [markdown]
# ## Analyzing Strategy Holdings, Leverage, Exposure, and Sector Allocations

# %%
import warnings

# %%
import pandas as pd
import pyfolio as pf
from IPython.display import Markdown, display
from openbb import obb

# %%
warnings.filterwarnings("ignore")
obb.user.preferences.output_type = "dataframe"

# %% [markdown]
# Load the mean reversion performance data

# %%
perf = pd.read_pickle("mean_reversion.pickle")

# %% [markdown]
# Extract returns, positions, and transactions from Zipline performance DataFrame

# %%
returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf)

# %% [markdown]
# Rename position columns to stock symbols and cash

# %%
positions.columns = [col.symbol for col in positions.columns[:-1]] + ["cash"]

# %% [markdown]
# Get the list of symbols

# %%
symbols = positions.columns[:-1].tolist()

# %% [markdown]
# Get screener data for the symbols

# %%
screener_data = obb.equity.profile(symbols, provider="yfinance")
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ATVI?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ATVI&crumb=cd3AOpgdw9C
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/BRK_B?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=BRK_B&crumb=cd3AOpgdw9C
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/PXD?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=PXD&crumb=cd3AOpgdw9C

# %% [markdown]
# Create a sector map from the screener data

# %%
sector_map = (
    screener_data[["symbol", "sector"]]
    .set_index("symbol")
    .reindex(symbols)
    .fillna("Unknown")
    .to_dict()["sector"]
)

# %% [markdown]
# Get historical price data for SPY

# %%
spy = obb.equity.price.historical(
    "SPY",
    start_date=returns.index.min(),
    end_date=returns.index.max(),
    provider="yfinance",
)

# %% [markdown]
# Convert the index to datetime and calculate the benchmark returns

# %%
spy.index = pd.to_datetime(spy.index)
benchmark_returns = spy.close.pct_change()
benchmark_returns.name = "SPY"
benchmark_returns = benchmark_returns.tz_localize("UTC").filter(returns.index)

# %% [markdown]
# Plot the holdings

# %%
pf.plotting.plot_holdings(returns, positions)
# Out:
# <Axes: title={'center': 'Total holdings'}, ylabel='Holdings'>

# %% [markdown]
# Plot the long and short holdings

# %%
pf.plotting.plot_long_short_holdings(returns, positions)
# Out:
# <Axes: title={'center': 'Long and short holdings'}, ylabel='Holdings'>

# %% [markdown]
# Plot the gross leverage

# %%
pf.plotting.plot_gross_leverage(returns, positions)
# Out:
# <Axes: title={'center': 'Gross leverage'}, ylabel='Gross leverage'>

# %% [markdown]
# Plot the exposures

# %%
pf.plotting.plot_exposures(returns, positions)
# Out:
# <Axes: title={'center': 'Exposure'}, ylabel='Exposure'>

# %% [markdown]
# Show and plot the top positions

# %%
positions_alloc = pf.pos.get_percent_alloc(positions)
pf.plotting.show_and_plot_top_positions(returns, positions_alloc, show_and_plot=2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 long positions of all time</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>VRX</th>
#       <td>2.67%</td>
#     </tr>
#     <tr>
#       <th>ORLY</th>
#       <td>2.24%</td>
#     </tr>
#     <tr>
#       <th>LRCX</th>
#       <td>2.19%</td>
#     </tr>
#     <tr>
#       <th>NVDA</th>
#       <td>2.19%</td>
#     </tr>
#     <tr>
#       <th>DAL</th>
#       <td>2.18%</td>
#     </tr>
#     <tr>
#       <th>EFX</th>
#       <td>2.18%</td>
#     </tr>
#     <tr>
#       <th>LNKD</th>
#       <td>2.17%</td>
#     </tr>
#     <tr>
#       <th>PRGO</th>
#       <td>2.14%</td>
#     </tr>
#     <tr>
#       <th>ALXN</th>
#       <td>2.13%</td>
#     </tr>
#     <tr>
#       <th>LLY</th>
#       <td>2.13%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 short positions of all time</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>DAL</th>
#       <td>-2.14%</td>
#     </tr>
#     <tr>
#       <th>MON</th>
#       <td>-2.14%</td>
#     </tr>
#     <tr>
#       <th>QCOM</th>
#       <td>-2.12%</td>
#     </tr>
#     <tr>
#       <th>TWTR</th>
#       <td>-2.10%</td>
#     </tr>
#     <tr>
#       <th>INTC</th>
#       <td>-2.10%</td>
#     </tr>
#     <tr>
#       <th>WMT</th>
#       <td>-2.09%</td>
#     </tr>
#     <tr>
#       <th>CSX</th>
#       <td>-2.09%</td>
#     </tr>
#     <tr>
#       <th>PM</th>
#       <td>-2.09%</td>
#     </tr>
#     <tr>
#       <th>CTSH</th>
#       <td>-2.09%</td>
#     </tr>
#     <tr>
#       <th>TXN</th>
#       <td>-2.08%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 positions of all time</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>VRX</th>
#       <td>2.67%</td>
#     </tr>
#     <tr>
#       <th>ORLY</th>
#       <td>2.24%</td>
#     </tr>
#     <tr>
#       <th>LRCX</th>
#       <td>2.19%</td>
#     </tr>
#     <tr>
#       <th>NVDA</th>
#       <td>2.19%</td>
#     </tr>
#     <tr>
#       <th>DAL</th>
#       <td>2.18%</td>
#     </tr>
#     <tr>
#       <th>EFX</th>
#       <td>2.18%</td>
#     </tr>
#     <tr>
#       <th>LNKD</th>
#       <td>2.17%</td>
#     </tr>
#     <tr>
#       <th>PRGO</th>
#       <td>2.14%</td>
#     </tr>
#     <tr>
#       <th>MON</th>
#       <td>2.14%</td>
#     </tr>
#     <tr>
#       <th>ALXN</th>
#       <td>2.13%</td>
#     </tr>
#   </tbody>
# </table>
# <Axes: title={'center': 'Portfolio allocation over time, only top 10 holdings'}, xlabel='index', ylabel='Exposure by holding'>

# %% [markdown]
# Plot the sector allocations

# %%
sector_alloc = pf.pos.get_sector_exposures(positions, symbol_sector_map=sector_map)
pf.plotting.plot_sector_allocations(returns, sector_alloc=sector_alloc)
# Out:
# <Axes: title={'center': 'Sector allocation over time'}, ylabel='Exposure by sector'>

# %% [markdown]
# **Jason Strimpel** is the founder of <a href='https://pyquantnews.com/'>PyQuant News</a> and co-founder of <a href='https://www.tradeblotter.io/'>Trade Blotter</a>. His career in algorithmic trading spans 20+ years. He previously traded for a Chicago-based hedge fund, was a risk manager at JPMorgan, and managed production risk technology for an energy derivatives trading firm in London. In Singapore, he served as APAC CIO for an agricultural trading firm and built the data science team for a global metals trading firm. Jason holds degrees in Finance and Economics and a Master's in Quantitative Finance from the Illinois Institute of Technology. His career spans America, Europe, and Asia. He shares his expertise through the <a href='https://pyquantnews.com/subscribe-to-the-pyquant-newsletter/'>PyQuant Newsletter</a>, social media, and has taught over 1,000+ algorithmic trading with Python in his popular course **<a href='https://gettingstartedwithpythonforquantfinance.com/'>Getting Started With Python for Quant Finance</a>**. All code is for educational purposes only. Nothing provided here is financial advise. Use at your own risk.
